# %%
# !pip install nbdime

# %%
# !nbdiff DeepLearningHW2.ipynb dporiginal.ipynb
# Out:
# nbdiff DeepLearningHW2.ipynb dporiginal.ipynb
# --- DeepLearningHW2.ipynb  2022-10-25 19:16:18.740026
# +++ dporiginal.ipynb  2022-10-25 19:00:48.749376
# ## added /cells/0/id:
# +  a85b5fa7
#
# ## deleted /cells/0/metadata/id:
# -  W_5ZhvIqpdat
#
# ## deleted /cells/1:
# -  markdown cell:
# -    source:
# -      [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/SzabolcsWeyde/DeepLearningHW2/blob/b48faedc80c15318e090e7878b297daa7eb59bbf/DeepLearningHW2.ipynb)
#
# ## replaced (type changed from int to NoneType) /cells/2/execution_count:
# -  1
# +  None
#
# ## added /cells/2/id:
# +  e62bc970
#
# ## deleted /cells/2/metadata/id:
# -  HOU2IE2upfX6
#
# ## replaced (type changed from int to NoneType) /cells/3/execution_count:
# -  2
# +  None
#
# ## added /cells/3/id:
# +  39c8fc02
#
# ## deleted /cells/3/metadata/id:
# -  wGxlOrVkqbkJ
#
# ## replaced (type changed from int to NoneType) /cells/4/execution_count:
# -  3
# ...
